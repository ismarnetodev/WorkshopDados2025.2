# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("brasil.csv")
df
# Out:
#     temporada  rodada      time_casa time_visitante  gols_casa  \
# 0        2023       1       Flamengo      São Paulo          2
# 1        2023       1      Palmeiras    Corinthians          1
# 2        2023       1    Atlético-MG  Internacional          3
# 3        2023       1     Fluminense         Santos          2
# 4        2023       1       Botafogo          Goiás          1
# 5        2023       2      São Paulo      Palmeiras          0
# 6        2023       2    Corinthians       Flamengo          1
# 7        2023       2  Internacional     Fluminense          2
# 8        2023       2         Santos       Botafogo          0
# 9        2023       2          Goiás    Atlético-MG          1
# 10       2023       3       Flamengo  Internacional          2
# 11       2023       3      Palmeiras         Santos          3
# 12       2023       3    Atlético-MG    Corinthians          2
# 13       2023       3     Fluminense          Goiás          1
# ...

# %%
# Este comando vai listar todas as colunas da sua tabela (DataFrame)
print(df.columns)
# Out:
# Index(['temporada', 'rodada', 'time_casa', 'time_visitante', 'gols_casa',
#        'gols_visitante', 'posse_bola_casa', 'chutes_casa', 'chutes_visitante',
#        'escanteios_casa', 'escanteios_visitante', 'faltas_casa',
#        'faltas_visitante', 'cartoes_amarelos_casa',
#        'cartoes_amarelos_visitante', 'cartoes_vermelhos_casa',
#        'cartoes_vermelhos_visitante', 'resultado'],
#       dtype='object')

# %%
# Exemplo de correção se o nome correto for 'diâmetro'
df.plot(kind="scatter", x="temporada", y="gols_visitante")

plt.show()

# %%
from sklearn import linear_model

modelo = linear_model.LinearRegression()
x = df[["gols_casa"]]
y = df[["gols_visitante"]]

modelo.fit(x, y)
# Out:
# LinearRegression()

# %%
print(modelo.predict([[2023]])[0][0])
# Out:
# -511.25633802816884
# c:\Users\ismar\Desktop\PASTA NETO\fabrica\fabrica_ml\fabrica_ml1\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
